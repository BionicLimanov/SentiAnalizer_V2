# %% [markdown]
# <a href="https://colab.research.google.com/github/BionicLimanov/bioniclimanov.github.io/blob/main/privateUse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
# !pip install sastrawi
# !pip install newspaper3k

from nltk.tokenize import punkt
import nltk
from textblob import TextBlob
from newspaper import Article
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
import string
import re


from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
from nltk.tokenize import word_tokenize 
 

stop_factory = StopWordRemoverFactory().get_stop_words() #load defaul stopword
more_stopword = ['daring', 'online'] #menambahkan stopword
kalimat = "Andi kerap melakukan adalah transaksi rutin secara daring atau online. Menurut Andi belanja online lebih praktis & murah."
# kalimat = kalimat.lower()
# kalimat = kalimat.strip()
# kalimat = re.sub(r"\d+", "", kalimat)
# kalimat = kalimat.translate(str.maketrans("","",string.punctuation))
kalimat = str.maketrans("","", string.punctuation)
kalimat = kalimat.translate
data = stop_factory + more_stopword #menggabungkan stopword

dictionary = ArrayDictionary(data)
str = StopWordRemover(dictionary)
tokens = nltk.tokenize.word_tokenize(str.remove(kalimat))
 
print(tokens)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-a7823ce221cb> in <module>()
#      25 # kalimat = re.sub(r"\d+", "", kalimat)
#      26 # kalimat = kalimat.translate(str.maketrans("","",string.punctuation))
# ---> 27 kalimat = str.maketrans("","", string.punctuation)
#      28 kalimat = kalimat.translate
#      29 data = stop_factory + more_stopword #menggabungkan stopword
#
# ...

# %%
# !pip install sastrawi 
# !pip install article
# !pip install newspaper3k


from newspaper import Article
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
stop_factory = StopWordRemoverFactory()
more_stopword = ['dengan', 'ia', 'bahwa', 'oleh', ',', 'bbca']
testkalimat = 'aku adalah anak gembala selalu riang serta gembira, aku selalu siap memborong saham bbca'

data = stop_factory.get_stop_words()
stopword = stop_factory.create_create_stop_word_remover()

# url = 'https://docs.google.com/spreadsheets/d/1qadUuIWOS_EM79OiTh-hH79PBpDtwElyCyPY7m4QWsc/edit?usp=sharing' # klo article indo nlp nya gk paham jdi klo gk di tl dulu ya pake sastrawi
# url = 'https://investasi.kontan.co.id/news/harga-saham-wskt-turun-14-ytd-analis-rekomendasi-beli-simak-alasannya'
# data = pd.read_csv('https://raw.githubusercontent.com/amankharwal/Website-data/master/reviews%20data.csv')

stop = stopword.remove(testkalimat)
print("kalimat auto : " + testkalimat)
print("sudah bersih : " + stop)
# print(data)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for article: filename=article-0.1.1-py3-none-any.whl size=1065 sha256=dfcfc055920597e01b1aa0bb2803aa063cc61a51fb2ebe6d3a60d6dddd48ae3f
#   Stored in directory: /root/.cache/pip/wheels/b7/c6/4c/d69c7b9cc5e97ac777e6338421fff7d26fcb7a793c2e3bdeb7
# Successfully built article
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-ad2e75dfdd4a> in <module>()
#      17 # data = pd.read_csv('https://raw.githubusercontent.com/amankharwal/Website-data/master/reviews%20data.csv')
#      18
# ---> 19 stop = stopword.remove(testkalimat)
# ...

# %%
# ! pip install sastrawi

from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
from nltk.tokenize import word_tokenize 
stop_factory = StopWordRemoverFactory()
more_stopword = ['dengan', 'ia', 'bahwa', 'oleh' ',', 'bbca', 'bbri', 'limacorp']
data = stop_factory.get_stop_words()
stopword = stop_factory.create_stop_word_remover()
kalimat = 'aku adalah anak gembala, selalu dengan bbca'
filter = data + more_stopword
print(filter)
print('\n\n')

dictionary = ArrayDictionary(filter)
str = StopWordRemover(dictionary)
tokens = nltk.tokenize.word_tokenize(str.remove(kalimat))
 
print(tokens)

#complete
# Out:
# ['yang', 'untuk', 'pada', 'ke', 'para', 'namun', 'menurut', 'antara', 'dia', 'dua', 'ia', 'seperti', 'jika', 'jika', 'sehingga', 'kembali', 'dan', 'tidak', 'ini', 'karena', 'kepada', 'oleh', 'saat', 'harus', 'sementara', 'setelah', 'belum', 'kami', 'sekitar', 'bagi', 'serta', 'di', 'dari', 'telah', 'sebagai', 'masih', 'hal', 'ketika', 'adalah', 'itu', 'dalam', 'bisa', 'bahwa', 'atau', 'hanya', 'kita', 'dengan', 'akan', 'juga', 'ada', 'mereka', 'sudah', 'saya', 'terhadap', 'secara', 'agar', 'lain', 'anda', 'begitu', 'mengapa', 'kenapa', 'yaitu', 'yakni', 'daripada', 'itulah', 'lagi', 'maka', 'tentang', 'demi', 'dimana', 'kemana', 'pula', 'sambil', 'sebelum', 'sesudah', 'supaya', 'guna', 'kah', 'pun', 'sampai', 'sedangkan', 'selagi', 'sementara', 'tetapi', 'apakah', 'kecuali', 'sebab', 'selain', 'seolah', 'seraya', 'seterusnya', 'tanpa', 'agak', 'boleh', 'dapat', 'dsb', 'dst', 'dll', 'dahulu', 'dulunya', 'anu', 'demikian', 'tapi', 'ingin', 'juga', 'nggak', 'mari', 'nanti', 'melainkan',
# ...

# %%
# url = 'https://exodus.stockbit.com/stream/symbol/BBCA?category=all&beforelastpost=100&keyword=&from=100to=&clean=0&limit=100'
url = 'https://exodus.stockbit.com/stream/symbol/BBCA?category=all&beforelastpost=1&lastpost=9315162&keyword=&from=&to=&clean=0&limit=100'
superAdmin1 = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..5kqFPiKEmN9VLRT64z-sEd_SPm-tub-bIBbCq3zv_kY'
# result = requests.get(url)
# print(result.text)
import urllib
from urllib.request import Request, urlopen
import json
import pandas as pd 

user_agent = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'
head = { 'User-Agent' : user_agent }
request = urllib.request.Request(url,headers = head)
request.add_header("authorization", superAdmin1)

contents = urllib.request.urlopen(request).read()
b = json.loads(contents)
print(b)
new_my_dict = b
df = pd.DataFrame.from_dict(new_my_dict) 
df.to_csv (r'test2.csv', index = False, header=True)
# Out:
# {'message': '100 stream post(s) retrieved', 'data': [{'postid': 9315043, 'titleurl': '', 'title': '', 'content': '[%UCyj%] stockbit bgst', 'content_original': '$BBCA stockbit bgst', 'created': '2022-08-10 09:53:29', 'created_display': '10 Aug 22, 09:53', 'updated': '0000-00-00 00:00:00', 'userid': 279107, 'is_author': 0, 'username': 'primaadipradana', 'fullname': 'Prima Adi P', 'avatar': 'male/ToyFaces_Colored_BG_31-min.png', 'official': 0, 'user_priv': 0, 'ispro': 1, 'ispinned': 0, 'trending': 0, 'replies': '2', 'noreply': 0, 'likes': 2, 'dislikes': 0, 'reposted': 0, 'repostedfrom': None, 'liked': 0, 'likers': '', 'saved': 0, 'images': [], 'polling': [], 'attachment': [], 'parent_postid': 9315043, 'disliked': 0, 'follow': 0, 'reports': [], 'newsfeed_source': '', 'newsfeed_label': '', 'newsfeed_img': '', 'linkpreview': '', 'total_view': 0, 'tradeshare': '', 'total_share': '0', 'target_price': [], 'analytics': None, 'country': 'ID', 'last_reply_date': 1660100009, 'isnews': 0, 'isrepor
# ...

# %%
#INI MODELNYA SO FAR MKIII 

! pip install newspaper3k
! pip install sastrawi


from nltk.tokenize import punkt
import nltk
from textblob import TextBlob
from newspaper import Article
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist
import string
import re

import urllib
from urllib.request import Request, urlopen
import json
import pandas as pd 


# import panda as pd
# df = pd.read_excel('https://docs.google.com/spreadsheets/d/18Eb6l2eSCn4wqmckaLOk0ceiTgA6Jyko-otwrgL-PWE/edit?usp=sharing', sheet_name = 'datascrape_test00', usecols=['k'])
# url = 'https://www.cnbcindonesia.com/market/20220809113539-17-362240/elon-musk-mau-borong-rp-75-t-saham-nikel-terbang' 
# url = 'https://www.theguardian.com/australia-news/2022/aug/09/man-charged-with-over-deaths-of-woman-and-her-son-in-stretton-in-brisbane'
# url = 'https://investor.id/market-and-corporate/295118/ada-kabar-baik-untuk-pasar-saham-dalam-sepekan-ke-depan' # klo article indo nlp nya gk paham jdi klo gk di tl dulu ya pake sastrawi
# url = 'https://docs.google.com/spreadsheets/d/1jSWHGBPsYt4e452BLIBe0AjG74AauQccyJQuuW0vHb8/edit?usp=sharing'
# url = 'https://docs.google.com/spreadsheets/d/1gwhthMc-F_JSRu3wjkvkp-n4fPN5nqaOzJZ8PjNtk4s/edit?usp=sharing'

drive = 'https://docs.google.com/spreadsheets/d/1qA2qkZeEy_qKQ7PPil2COnZqL9Nj33GX1VsXEel4pK8/edit?usp=sharing' #4000 comment bbri -dri jeffry
drive2 = 'https://docs.google.com/spreadsheets/d/10V5xLmMi10ZDJ8S08xLd3ONeVbxsy1sL_cFlZLgqcpg/edit?usp=sharing'
url1 = 'https://raw.githubusercontent.com/amankharwal/Website-data/master/reviews%20data.csv'
url2 = 'https://www.cnbcindonesia.com/market/20210101194418-17-212969/awas-bubble-saham-tesla-sudah-kemahalan'

url = 'https://exodus.stockbit.com/stream/symbol/BBCA?category=all&beforelastpost=1&lastpost=9315162&keyword=&from=&to=&clean=0&limit=50'
superAdmin1 = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..5kqFPiKEmN9VLRT64z-sEd_SPm-tub-bIBbCq3zv_kY'
bbca = 'https://raw.githubusercontent.com/BionicLimanov/reviewsdata/main/4k_bbri_comment%20-%20Sheet1%20(1).csv'
# url sm superadminnya error 401 butuh super admin baru

# user_agent = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'
# head = { 'User-Agent' : user_agent }
# request = urllib.request.Request(url,headers = head)
# request.add_header("authorization", superAdmin1)

# contents = urllib.request.urlopen(request).read()
# b = json.loads(contents)
# print(b) #cm buat mastiin aja yg di load bener
# new_my_dict = b
# df = pd.DataFrame.from_dict(new_my_dict) 
# df.to_csv (r'test2.csv', index = False, header=True)


# article = Article(drive)
# article.download()
# article.parse() 
# article.nlp()
# text = article.text
# print(article.summary)
# print('\n')

df = pd.read_csv(bbca, error_bad_lines=False)
# df = pd.read_csv(url1, sep='\n', header=None)
data = df.dropna()
text = df.to_string()

lowercasetext = text.lower()
lowercasetext = lowercasetext.translate(str.maketrans("","",string.punctuation))
lowercasetext = re.sub(r"\d+", "", lowercasetext)
lowercasetext = lowercasetext.strip()
tokens = nltk.tokenize.word_tokenize(lowercasetext)
print(tokens)

#test darurat
custom_stopwords = ['dengan', 'ia', 'bahwa', 'oleh' ',', 'limacorp', 'lia', 'itzy', 'papi', 'elon', 'tele', 'yg']
list_saham = 'https://docs.google.com/spreadsheets/d/1SCDTDsI2-UZd0SXLrRS3DVpgxLFvpMdoFeixgFZdjkM/edit?usp=sharing'
custom_stopwords.append(list_saham)
list_stopwords = set(stopwords.words('indonesian') + custom_stopwords)
tokens_dah_bersih = [word for word in tokens if not word in list_stopwords]
print(tokens_dah_bersih)

#ngitung freq kemunculan kata
kemunculan = nltk.FreqDist(tokens_dah_bersih)
kemunculan = kemunculan.most_common()
print(kemunculan)
print('\n\n')

#buat ngerubah list jdi string spy bisa dicerna sm blob
pinal_text = ' '.join(str(e) for e in kemunculan)
blob = TextBlob(pinal_text)
sentiment = blob.sentiment.polarity # -1 smpe 1
if sentiment >= 0.05 :
  print("this whole thing is positive...NICE")
elif sentiment <= -0.05 : 
  print("WAH ramalan LALA gabagus nih om...NEGATIF")
else : 
  print("NETRAL SIH INI")

print(sentiment)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ...

# %%
from google.colab import files

# selected_testing.to_excel('dataset_saham_icimtech.xlsx')
# files.download('dataset_saham_icimtech.xlsx')
kemunculan.to_excel('freqBBRI.xlsx')
files.download('freqBBRI.xlsx')

# %%
#========================================================= RUN THIS FIRST =========================================================

# !pip install -U deep-translator
# !pip install sastrawi
# !pip install pandas
# !pip install torch torchvision
# !pip install vaderSentiment
# !pip install textblob
# !pip install article
# !pip install -U textblob
# !python -m textblob.download_corpora
# !pip install requests

# %%
#automate labeling

# https://docs.google.com/spreadsheets/d/1qA2qkZeEy_qKQ7PPil2COnZqL9Nj33GX1VsXEel4pK8/edit?usp=sharing
# https://raw.githubusercontent.com/amankharwal/Website-data/master/reviews%20data.csv
# https://raw.githubusercontent.com/BionicLimanov/reviewsdata/main/4k_bbri_comment%20-%20Sheet1%20(1).csv

import nltk
import re
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download("vader_lexicon")
import pandas as pd
nltk.download('stopwords')
from nltk.corpus import stopwords

data = pd.read_csv("https://raw.githubusercontent.com/BionicLimanov/reviewsdata/main/4k_bbri_comment%20-%20Sheet1%20(1).csv", error_bad_lines=False)
# data = pd.read_csv("https://raw.githubusercontent.com/BionicLimanov/labelbbca/main/4k_bbca_comment%20-%20merge-csv.com__62f491239130a.csv", sep=',', header=None, error_bad_lines=False)
# data = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/reviews%20data.csv")
data = data.dropna()

lower = [word.lower() for word in data]
lowercasetext = ' '.join(str(e) for e in lower)
lowercasetext = re.sub(r"\d+", "", lowercasetext)
lowercasetext = re.sub(r"\$", "", lowercasetext)
lowercasetext = lowercasetext.strip()
tokens = nltk.tokenize.word_tokenize(lowercasetext)
custom_stopwords = ['dengan', 'ia', 'bahwa', 'oleh' ',', 'lia', 'itzy', 'papi', 'elon', 'tele', 'yg']
list_saham = 'https://docs.google.com/spreadsheets/d/1SCDTDsI2-UZd0SXLrRS3DVpgxLFvpMdoFeixgFZdjkM/edit?usp=sharing'
custom_stopwords.append(list_saham)
list_stopwords = set(stopwords.words('indonesian') + custom_stopwords)
tokens_dah_bersih = [word for word in tokens if not word in list_stopwords]
kemunculan = nltk.FreqDist(tokens_dah_bersih)
kemunculan = kemunculan.most_common()
kemunculan = ' '.join(str(x) for x in kemunculan)
print(data.head())
print('\n')
sentiments = SentimentIntensityAnalyzer()
data["Positive"] = [sentiments.polarity_scores(i)["pos"] for i in data["reviews"]]
data["Negative"] = [sentiments.polarity_scores(i)["neg"] for i in data["reviews"]]
data["Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in data["reviews"]]
data['Compound'] = [sentiments.polarity_scores(i)["compound"] for i in data["reviews"]]
data.head()

score = data["Compound"].values
sentiment = []
for i in score:
    if i >= 0.05 :
        sentiment.append('Positive')
    elif i <= -0.05 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
data["Sentiment"] = sentiment
data.head()

print(data["Sentiment"].value_counts())
# data.to_csv("labelled_bbca.csv")
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                              reviews
# 0  ada 5 saham yg sudah di analisis secara teknik...
# 1  [%rhEv%] akan kembali ke harga fundamentalnya....
# 2  [%TxLY%]\nSistem stokbit atau Securitas Securi...
# 3  [%fSwV%] [%wZFN%] [%BUaU%] [%eKLb%] [%IYah%] \...
# 4  Mari gabung KOMUNITAS SAHAM dengan pembahasan ...
#
#
# Neutral     2913
# Positive     818
# Negative     359
# Name: Sentiment, dtype: int64

# %%
##INI MODELNYA SO FAR MKIV hasil ngebut seminggu
#fitur auto scrape = blm bisa karna error 401
#bisa input comment 
#++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ tinggal di run pak ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++


# !pip install -U deep-translator
# !pip install sastrawi
# !pip install pandas
# !pip install torch torchvision
# !pip install vaderSentiment
# !pip install textblob
# !pip install article



import re
import torch
from torch.utils.data import Dataset, DataLoader
from deep_translator import GoogleTranslator
import nltk
from nltk.corpus import stopwords
import pandas as pd
from textblob.classifiers import NaiveBayesClassifier
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
nltk.download('stopwords')
import nltk
nltk.download('punkt')
nltk.download('popular')
from textblob import TextBlob
from google.colab import drive


# ribut ribut perusahaan consumer goods, kalian jangan sampai kelewatan bahwa ada perusahaan yang inovatif dan vatif vatif lainnya berhasil membuat 1 produk untuk merebut pasar kemasan tupperware dan pasar es krim susu. Sabana mendunia $ULTJ $DLTA $TSPC $BBCA $BBRI
# train = 'https://raw.githubusercontent.com/BionicLimanov/textblob_train/main/blob_train.csv'
# test = 'https://raw.githubusercontent.com/BionicLimanov/labelbbca/main/4k_bbca_comment%20-%20merge-csv.com__62f491239130a.csv'
# cl = NaiveBayesClassifier(train)
# with open('train.csv', 'r') as fp:
#   cl = NaiveBayesClassifier(fp, format="csv")
# print('\n\n')
# train = [
# ('I love this sandwich.', 'pos'),
# ('this is an amazing place!', 'pos'),
# ('I feel very good about these beers.', 'pos'),
# ('this is my best work.', 'pos'),
# ("what an awesome view", 'pos'),
# ('I do not like this restaurant', 'neg'),
# ('I am tired of this stuff.', 'neg'),
# ("I can't deal with this", 'neg'),
# ('he is my sworn enemy!', 'neg'),
# ('my boss is horrible.', 'neg')
# ]
# test = [
# ('the beer was good.', 'pos'),
# ('I do not enjoy my job', 'neg'),
# ("I ain't feeling dandy today.", 'neg'),
# ("I feel amazing!", 'pos'),
# ('Gary is a friend of mine.', 'pos'),
# ("I can't believe I'm doing this.", 'neg')
# ]


#data = input()
drive.mount("/content/drive", force_remount=True)
# %ls ./drive/MyDrive/data_ori/CS-3k/LABELLED_BBRI_MANUAL.xlsx
# testing_manual = pd.read_excel('./drive/MyDrive/data_ori/CS-3k/LABELLED_BBRI_MANUAL.xlsx')
testing_manual = pd.read_excel('./drive/MyDrive/data_ori/CS-3k/LABELLED_BBRI_MANUAL.xlsx')
testing_manual = testing_manual.fillna(0)
testing_manual['polar'] = testing_manual['polar'].astype(int)
testing_manual
testing_manual = ' '.join(str(e) for e in testing_manual)
translated = GoogleTranslator(source='auto', target='en').translate(testing_manual) 
# lowercasetext = testing_manual.lower()
lower = [word.lower() for word in testing_manual]
lowercasetext = ' '.join(str(e) for e in lower)

lowercasetext = re.sub(r"\d+", "", lowercasetext)
lowercasetext = re.sub(r"\$", "", lowercasetext)
lowercasetext = lowercasetext.strip()
tokens = nltk.tokenize.word_tokenize(lowercasetext)
custom_stopwords = ['dengan', 'ia', 'bahwa', 'oleh' ',', 'lia', 'itzy', 'papi', 'elon', 'tele', 'yg']
list_saham = 'https://docs.google.com/spreadsheets/d/1SCDTDsI2-UZd0SXLrRS3DVpgxLFvpMdoFeixgFZdjkM/edit?usp=sharing'
custom_stopwords.append(list_saham)
list_stopwords = set(stopwords.words('indonesian') + custom_stopwords)
tokens_dah_bersih = [word for word in tokens if not word in list_stopwords]
kemunculan = nltk.FreqDist(tokens_dah_bersih)
kemunculan = kemunculan.most_common()
#buat ngerubah list jdi string spy bisa dicerna sm blob
text = ' '.join(str(e) for e in kemunculan)
text = TextBlob(text)
blobpolarity = text.sentiment.polarity
print('\n\npre trained textblob with deep-translator and sastrawi stop_word yield')
print(blobpolarity)
if blobpolarity >= 0.05 :
  print("this thing is positive...")
elif blobpolarity <= -0.05 : 
  print("WAH ramalan LALA gabagus nih om...NEGATIF")
else : 
  print("NETRAL SIH INI")
print('\n\n')



#mencoba pake main dan 
def sentimentScores(lowercasetext):
    sentiment_object = SentimentIntensityAnalyzer()
    hasil_bagi = sentiment_object.polarity_scores(lowercasetext)
    print(hasil_bagi)
    print(hasil_bagi['neg']*100, "% Negative")
    print(hasil_bagi['neu']*100, "% Neutral")
    print(hasil_bagi['pos']*100, "% Positive")
    if hasil_bagi['compound'] >= 0.05 :
        print("Positive")
    elif hasil_bagi['compound'] <= - 0.05 :
        print("Negative")
    else :
        print("Neutral")

if __name__ == "__main__" :

    print('hasil dari vader pre trained data yield')
    sentimentScores(lowercasetext)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# ...

# %%
arr = [4,6,7,8,3,8,3,4,6]

nas = 0
nas = arr[0] + arr[1] + arr[2] + arr[3] + arr[4] + arr[5] + arr[6] + arr[7] + arr[8] 
print(nas)


ans = 0
for x in range(0, len(arr)):
  ans = ans + arr[x]
  x = x+1
print(ans)


lazy = 0
lazy = sum(arr)
print(lazy)


hayuk = print(sum(arr))
# Out:
# 49
# 49
# 49
# 49
